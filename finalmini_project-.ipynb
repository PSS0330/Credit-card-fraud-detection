# %%
# Importing the libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 500)

# %%
# Reading the dataset
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Cheking percent of missing values in columns
df_missing_columns = (round(((df.isnull().sum()/len(df.index))*100),2).to_frame('null')).sort_values('null', ascending=False)
df_missing_columns
# Out:
#         null
# Time     0.0
# V16      0.0
# Amount   0.0
# V28      0.0
# V27      0.0
# V26      0.0
# V25      0.0
# V24      0.0
# V23      0.0
# V22      0.0
# V21      0.0
# V20      0.0
# V19      0.0
# V18      0.0
# V17      0.0
# V15      0.0
# V1       0.0
# V14      0.0
# V13      0.0
# V12      0.0
# V11      0.0
# V10      0.0
# V9       0.0
# V8       0.0
# V7       0.0
# V6       0.0
# V5       0.0
# V4       0.0
# V3       0.0
# V2       0.0
# Class    0.0

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
normal_share = round((classes[0]/df['Class'].count()*100),2)
normal_share
# Out:
# 99.83

# %%
fraud_share = round((classes[1]/df['Class'].count()*100),2)
fraud_share
# Out:
# 0.17

# %%
# Bar plot for the number of fraudulent vs non-fraudulent transcations
sns.countplot(x='Class', data=df)
plt.title('Number of fraudulent vs non-fraudulent transcations')
plt.show()

# %%
# Bar plot for the percentage of fraudulent vs non-fraudulent transcations
fraud_percentage = {'Class':['Non-Fraudulent', 'Fraudulent'], 'Percentage':[normal_share, fraud_share]} 
df_fraud_percentage = pd.DataFrame(fraud_percentage) 
sns.barplot(x='Class',y='Percentage', data=df_fraud_percentage)
plt.title('Percentage of fraudulent vs non-fraudulent transcations')
plt.show()

# %%
# Creating fraudulent dataframe
data_fraud = df[df['Class'] == 1]
# Creating non fraudulent dataframe
data_non_fraud = df[df['Class'] == 0]

# %%
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(data_fraud['Time'],label='fraudulent',hist=False)
ax = sns.distplot(data_non_fraud['Time'],label='non fraudulent',hist=False)
ax.set(xlabel='Seconds elapsed between the transction and the first transction')
plt.show()

# %%
# Dropping the Time column
df.drop('Time', axis=1, inplace=True)

# %%
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(data_fraud['Amount'],label='fraudulent',hist=False)
ax = sns.distplot(data_non_fraud['Time'],label='non fraudulent',hist=False)
ax.set(xlabel='Transction Amount')
plt.show()

# %%
# Import library
from sklearn.model_selection import train_test_split

# %%
# Putting feature variables into X
X = df.drop(['Class'], axis=1)

# %%
# Putting target variable to y
y = df['Class']

# %%
# Splitting data into train and test set 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)

# %%
# Standardization method
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate the Scaler
scaler = StandardScaler()

# %%
# Fit the data into scaler and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 201788  2.023734 -0.429219 -0.691061 -0.201461 -0.162486  0.283718 -0.674694
# 179369 -0.145286  0.736735  0.543226  0.892662  0.350846  0.089253  0.626708
# 73138  -3.015846 -1.920606  1.229574  0.721577  1.089918 -0.195727 -0.462586
# 208679  1.851980 -1.007445 -1.499762 -0.220770 -0.568376 -1.232633  0.248573
# 206534  2.237844 -0.551513 -1.426515 -0.924369 -0.401734 -1.438232 -0.119942
#
#               V8        V9       V10       V11       V12       V13       V14  \
# 201788  0.192230  1.124319 -0.037763  0.308648  0.875063 -0.009562  0.116038
# 179369 -0.049137 -0.732566  0.297692  0.519027  0.041275 -0.690783  0.647121
# 73138   0.919341 -0.612193 -0.966197  1.106534  1.026421 -0.474229  0.641488
# 208679 -0.539483 -0.813368  0.785431 -0.784316  0.673626  1.428269  0.043937
# 206534 -0.449263 -0.717258  0.851668 -0.497634 -0.445482  0.324575  0.125543
#
# ...

# %%
# Transform the test set
X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 49089   1.229452 -0.235478 -0.627166  0.419877  1.797014  4.069574 -0.896223
# 154704  2.016893 -0.088751 -2.989257 -0.142575  2.675427  3.332289 -0.652336
# 67247   0.535093 -1.469185  0.868279  0.385462 -1.439135  0.368118 -0.499370
# 251657  2.128486 -0.117215 -1.513910  0.166456  0.359070 -0.540072  0.116023
# 201903  0.558593  1.587908 -2.368767  5.124413  2.171788 -0.500419  1.059829
#
#               V8        V9       V10       V11       V12       V13       V14  \
# 49089   1.036103  0.745991 -0.147304 -0.850459  0.397845 -0.259849 -0.277065
# 154704  0.752811  1.962566 -1.025024  1.126976 -2.418093  1.250341 -0.056209
# 67247   0.303698  1.042073 -0.437209  1.145725  0.907573 -1.095634 -0.055080
# 251657 -0.216140  0.680314  0.079977 -1.705327 -0.127579 -0.207945  0.307878
# 201903 -0.254233 -1.959060  0.948915 -0.288169 -1.007647  0.470316 -2.771902
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
# Check for NaN values in y_train
nan_indices = np.isnan(y_train)
if np.any(nan_indices):
    # Remove NaN values from both X_train and y_train
    X_train = X_train[~nan_indices]
    y_train = y_train[~nan_indices]

# %%
# Option 1: Drop rows with missing values
X_train.dropna(inplace=True)
y_train = y_train[X_train.index]

# Option 2: Impute missing values
# Option 2: Impute missing values
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")
X_train = imputer.fit_transform(X_train)

# %%
n_neighbors = 3
if n_neighbors > y_train.value_counts().min():
    print("Number of neighbors exceeds the number of samples in the minority class.")
n_neighbors = y_train.value_counts().min() - 1

# %%
from imblearn.over_sampling import SMOTE
# Instantiate SMOTE
sm = SMOTE(random_state=27,k_neighbors=n_neighbors)
# Fitting SMOTE to the train set
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %%
print('Before SMOTE oversampling X_train shape=', X_train.shape)
print('After SMOTE oversampling X_train shape=', X_train_smote.shape)
# Out:
# Before SMOTE oversampling X_train shape= (227845, 29)
# After SMOTE oversampling X_train shape= (454898, 29)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

# Creating KFold object with 5 splits
folds = KFold(n_splits=2, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifying score as roc-auc
model_cv = GridSearchCV(estimator=LogisticRegression(), param_grid=params, scoring='roc_auc', cv=folds, verbose=1, return_train_score=True)

# Fit the model
model_cv.fit(X_train_smote, y_train_smote)

# Results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results

# Plot of C versus train and validation scores
plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')

# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print("The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))

# Instantiate the model with best C
logistic_bal_smote = LogisticRegression(C=0.1)


logistic_bal_smote_model = logistic_bal_smote.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred = logistic_bal_smote_model.predict(X_train_smote)

# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)

TP = confusion[1, 1]  # true positive
TN = confusion[0, 0]  # true negatives
FP = confusion[0, 1]  # false positives
FN = confusion[1, 0]  # false negatives

# Accuracy
print("Accuracy:-", metrics.accuracy_score(y_train_smote, y_train_pred))

# Sensitivity
print("Sensitivity:-", TP / float(TP + FN))

# Specificity
print("Specificity:-", TN / float(TN + FP))
# Classification report
print(classification_report(y_train_smote, y_train_pred))

# Predicted probability
y_train_pred_proba_log_bal_smote = logistic_bal_smote_model.predict_proba(X_train_smote)[:, 1]

def draw_roc(actual, probs):
    fpr, tpr, thresholds = metrics.roc_curve(actual, probs, drop_intermediate=False)
    auc_score = metrics.roc_auc_score(actual, probs)
    plt.figure(figsize=(5, 5))
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba_log_bal_smote)

# Prediction on the test set
y_test_pred = logistic_bal_smote_model.predict(X_test)

# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)

# Accuracy
print("Accuracy:-", metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-", TP / float(TP + FN))

# Specificity
print("Specificity:-", TN / float(TN + FP))
# Classification report
print(classification_report(y_test, y_test_pred))
# ROC on the test set
# Predicted probability
y_test_pred_proba = logistic_bal_smote_model.predict_proba(X_test)[:, 1]
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# The highest test roc_auc is 0.9981164054955274 at C = 1000
# [[226034   1415]
#  [  5732 221717]]
# Accuracy:- 0.9842887856178748
# Sensitivity:- 0.9747987460925306
# Specificity:- 0.9937788251432189
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    227449
#            1       0.99      0.97      0.98    227449
#
#     accuracy                           0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# weighted avg       0.98      0.98      0.98    454898
# [[56489   377]
#  [   16    80]]
# Accuracy:- 0.9931006636002949
# Sensitivity:- 0.9747987460925306
# Specificity:- 0.9937788251432189
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.18      0.83      0.29        96
#
#     accuracy                           0.99     56962
# ...

# %%
from sklearn.model_selection import validation_curve
# Define range of hyperparameters
param_range = [0.001, 0.01, 0.1, 1, 10, 100]

# Calculate validation curve
train_scores, test_scores = validation_curve(LogisticRegression(), X_train_smote, y_train_smote, param_name="C", param_range=param_range, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot validation curve
plt.figure(figsize=(10, 6))
plt.plot(param_range, train_mean, color='blue', label='Training AUC')
plt.plot(param_range, test_mean, color='green', label='Validation AUC')
plt.title('Validation Curve for Logistic Regression')
plt.xlabel('C')
plt.ylabel('ROC_AUC')
plt.xscale('log')
plt.legend(loc='lower right')
plt.show()

# %%
# XGBoost
from xgboost import XGBClassifier

# Hyperparameter tuning with XGBoost
# Creating a KFold object
folds = 3

# Specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 'subsample': [0.3, 0.6, 0.9]}

# Specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# Set up GridSearchCV()
model_cv = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=folds, verbose=1, return_train_score=True)

# Fit the model
model_cv.fit(X_train_smote, y_train_smote)

# CV results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results

# Plotting
plt.figure(figsize=(16, 6))

param_grid = {'learning_rate': [0.2, 0.6], 'subsample': [0.3, 0.6, 0.9]}

for n, subsample in enumerate(param_grid['subsample']):

    # Subplot 1/n
    plt.subplot(1, len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample'] == subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

model_cv.best_params_

# Chosen hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating AUC
params = {'learning_rate': 0.6, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.9, 'objective': 'binary:logistic'}

# Fit model on training data
xgb_bal_smote_model = XGBClassifier(params=params)
xgb_bal_smote_model.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred = xgb_bal_smote_model.predict(X_train_smote)

# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Accuracy
print("Accuracy:-", metrics.accuracy_score(y_train_smote, y_train_pred))

# Sensitivity
print("Sensitivity:-", TP / float(TP + FN))

# Specificity
print("Specificity:-", TN / float(TN + FP))
# Classification report
print(classification_report(y_train_smote, y_train_pred))

# Predicted probability
y_train_pred_proba = xgb_bal_smote_model.predict_proba(X_train_smote)[:, 1]

# ROC_auc
auc = metrics.roc_auc_score(y_train_smote, y_train_pred_proba)
auc
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba)

# Predictions on the test set
y_test_pred = xgb_bal_smote_model.predict(X_test)
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Accuracy
print("Accuracy:-", metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-", TP / float(TP + FN))

# Specificity
print("Specificity:-", TN / float(TN + FP))
# Classification report
print(classification_report(y_test, y_test_pred))
# Predicted probability
y_test_pred_proba = xgb_bal_smote_model.predict_proba(X_test)[:, 1]
# ROC_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [10:07:31] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "params" } are not used.
#
# [[227443      6]
#  [     0 227449]]
# Accuracy:- 0.9999868102299856
# Sensitivity:- 0.9747987460925306
# Specificity:- 0.9937788251432189
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898
# [[56812    54]
#  [   20    76]]
# Accuracy:- 0.9987008883115059
# Sensitivity:- 0.9747987460925306
# Specificity:- 0.9937788251432189
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.58      0.79      0.67        96
#
# ...

# %%
from sklearn.model_selection import validation_curve
import matplotlib.pyplot as plt
import numpy as np
from xgboost import XGBClassifier

# Define range of hyperparameters
param_range = [0.2, 0.6, 1.0]

# Calculate validation curve
train_scores, test_scores = validation_curve(XGBClassifier(), X_train_smote, y_train_smote, param_name="learning_rate", param_range=param_range, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot validation curve
plt.figure(figsize=(10, 6))
plt.plot(param_range, train_mean, color='blue', marker='o', markersize=5, label='Training ROC_AUC')
plt.plot(param_range, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation ROC_AUC')
plt.title('Validation Curve for XGBoost')
plt.xlabel('Learning Rate')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.show()

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Create Gaussian Naive Bayes model
nb_model = GaussianNB()

# Perform cross-validation
cv_scores = cross_val_score(nb_model, X_train_smote, y_train_smote, cv=5, scoring='roc_auc')

# Print cross-validation scores
print("Cross-validation scores:", cv_scores)

# Fit the model
nb_model.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred_nb = nb_model.predict(X_train_smote)

# Confusion matrix
confusion_nb_train = metrics.confusion_matrix(y_train_smote, y_train_pred_nb)
print(confusion_nb_train)

# Accuracy
print("Accuracy:", metrics.accuracy_score(y_train_smote, y_train_pred_nb))

# Sensitivity
print("Sensitivity:", confusion_nb_train[1, 1] / float(confusion_nb_train[1, 1] + confusion_nb_train[1, 0]))

# Specificity
print("Specificity:", confusion_nb_train[0, 0] / float(confusion_nb_train[0, 0] + confusion_nb_train[0, 1]))

# Classification report
print(classification_report(y_train_smote, y_train_pred_nb))

# Predicted probability
y_train_pred_proba_nb = nb_model.predict_proba(X_train_smote)[:, 1]

# ROC curve
draw_roc(y_train_smote, y_train_pred_proba_nb)

# Predictions on the test set
y_test_pred_nb = nb_model.predict(X_test)

# Confusion matrix
confusion_nb_test = metrics.confusion_matrix(y_test, y_test_pred_nb)
print(confusion_nb_test)

# Accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_test_pred_nb))

# Sensitivity
print("Sensitivity:", confusion_nb_test[1, 1] / float(confusion_nb_test[1, 1] + confusion_nb_test[1, 0]))

# Specificity
print("Specificity:", confusion_nb_test[0, 0] / float(confusion_nb_test[0, 0] + confusion_nb_test[0, 1]))

# Classification report
print(classification_report(y_test, y_test_pred_nb))

# Predicted probability
y_test_pred_proba_nb = nb_model.predict_proba(X_test)[:, 1]

# ROC curve
draw_roc(y_test, y_test_pred_proba_nb)
# Out:
# Cross-validation scores: [0.98179943 0.98112793 0.98195092 0.98232192 0.9813417 ]
# [[222512   4937]
#  [ 24730 202719]]
# Accuracy: 0.9347831821639137
# Sensitivity: 0.8912723291814868
# Specificity: 0.9782940351463405
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94    227449
#            1       0.98      0.89      0.93    227449
#
#     accuracy                           0.93    454898
#    macro avg       0.94      0.93      0.93    454898
# weighted avg       0.94      0.93      0.93    454898
# [[55566  1300]
#  [   16    80]]
# Accuracy: 0.976896878620835
# Sensitivity: 0.8333333333333334
# Specificity: 0.9771392396159392
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.06      0.83      0.11        96
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.91      0.55     56962
# ...

# %%
# Stochastic Gradient Descent (SGD) Classifier
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV

# Hyperparameter tuning with SGD Classifier
param_grid_sgd = {
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1],
    'penalty': ['l1', 'l2', 'elasticnet'],
    'max_iter': [1000, 2000, 3000]
}

# Instantiate the SGD Classifier
sgd_model = SGDClassifier(loss='log', random_state=42)

# Perform Grid Search Cross Validation
grid_search_sgd = GridSearchCV(estimator=sgd_model, param_grid=param_grid_sgd, scoring='roc_auc', cv=2, verbose=2, n_jobs=-1)

# Fit the model
grid_search_sgd.fit(X_train_smote, y_train_smote)

# Get the best parameters
best_params_sgd = grid_search_sgd.best_params_

# Instantiate the model with best parameters
best_sgd_model = SGDClassifier(**best_params_sgd, loss='log', random_state=42)

# Fit the model on the training data
best_sgd_model.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred_sgd = best_sgd_model.predict(X_train_smote)

# Predictions on the test set
y_test_pred_sgd = best_sgd_model.predict(X_test)

# Confusion matrix - train set
confusion_sgd_train = confusion_matrix(y_train_smote, y_train_pred_sgd)
print("Confusion Matrix (Train Set):\n", confusion_sgd_train)

# Accuracy - train set
accuracy_train_sgd = metrics.accuracy_score(y_train_smote, y_train_pred_sgd)
print("Accuracy (Train Set):", accuracy_train_sgd)

# Sensitivity - train set
sensitivity_train_sgd = confusion_sgd_train[1, 1] / float(confusion_sgd_train[1, 1] + confusion_sgd_train[1, 0])
print("Sensitivity (Train Set):", sensitivity_train_sgd)

# Specificity - train set
specificity_train_sgd = confusion_sgd_train[0, 0] / float(confusion_sgd_train[0, 0] + confusion_sgd_train[0, 1])
print("Specificity (Train Set):", specificity_train_sgd)

# Classification report - train set
print("Classification Report (Train Set):\n", classification_report(y_train_smote, y_train_pred_sgd))

# Predicted probability - train set
y_train_pred_proba_sgd = best_sgd_model.predict_proba(X_train_smote)[:, 1]

# ROC curve
draw_roc(y_train_smote, y_train_pred_proba_sgd)

# Confusion matrix - test set
confusion_sgd_test = confusion_matrix(y_test, y_test_pred_sgd)
print("Confusion Matrix (Test Set):\n", confusion_sgd_test)

# Accuracy - test set
accuracy_test_sgd = metrics.accuracy_score(y_test, y_test_pred_sgd)
print("Accuracy (Test Set):", accuracy_test_sgd)

# Sensitivity - test set
sensitivity_test_sgd = confusion_sgd_test[1, 1] / float(confusion_sgd_test[1, 1] + confusion_sgd_test[1, 0])
print("Sensitivity (Test Set):", sensitivity_test_sgd)

# Specificity - test set
specificity_test_sgd = confusion_sgd_test[0, 0] / float(confusion_sgd_test[0, 0] + confusion_sgd_test[0, 1])
print("Specificity (Test Set):", specificity_test_sgd)

# Classification report - test set
print("Classification Report (Test Set):\n", classification_report(y_test, y_test_pred_sgd))

# Predicted probability - test set
y_test_pred_proba_sgd = best_sgd_model.predict_proba(X_test)[:, 1]


# ROC curve
draw_roc(y_test, y_test_pred_proba_sgd)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# Confusion Matrix (Train Set):
#  [[226182   1267]
#  [  6293 221156]]
# Accuracy (Train Set): 0.9833808897818852
# Sensitivity (Train Set): 0.9723322590998421
# Specificity (Train Set): 0.9944295204639282
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227449
#            1       0.99      0.97      0.98    227449
#
#     accuracy                           0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# weighted avg       0.98      0.98      0.98    454898
# Confusion Matrix (Test Set):
#  [[56540   326]
#  [   17    79]]
# Accuracy (Test Set): 0.9939784417681964
# Sensitivity (Test Set): 0.8229166666666666
# Specificity (Test Set): 0.9942672247036893
# Classification Report (Test Set):
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
# ...

# %%
# Define range of hyperparameters
param_range_alpha = [0.0001, 0.001, 0.01, 0.1, 1]
param_range_max_iter = [1000, 2000, 3000]

# Calculate validation curve for alpha
train_scores_alpha, test_scores_alpha = validation_curve(SGDClassifier(loss='log', random_state=42), X_train_smote, y_train_smote, param_name="alpha", param_range=param_range_alpha, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores
train_mean_alpha = np.mean(train_scores_alpha, axis=1)
train_std_alpha = np.std(train_scores_alpha, axis=1)
test_mean_alpha = np.mean(test_scores_alpha, axis=1)
test_std_alpha = np.std(test_scores_alpha, axis=1)

# Plot validation curve for alpha
plt.figure(figsize=(10, 6))
plt.plot(param_range_alpha, train_mean_alpha, color='blue', marker='o', markersize=5, label='Training ROC_AUC')
plt.plot(param_range_alpha, test_mean_alpha, color='green', linestyle='--', marker='s', markersize=5, label='Validation ROC_AUC')
plt.title('Validation Curve for SGD Classifier (Alpha)')
plt.xlabel('Alpha')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.xscale('log')
plt.show()

# Calculate validation curve for max_iter
train_scores_max_iter, test_scores_max_iter = validation_curve(SGDClassifier(loss='log', random_state=42), X_train_smote, y_train_smote, param_name="max_iter", param_range=param_range_max_iter, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores
train_mean_max_iter = np.mean(train_scores_max_iter, axis=1)
train_std_max_iter = np.std(train_scores_max_iter, axis=1)
test_mean_max_iter = np.mean(test_scores_max_iter, axis=1)
test_std_max_iter = np.std(test_scores_max_iter, axis=1)

# Plot validation curve for max_iter
plt.figure(figsize=(10, 6))
plt.plot(param_range_max_iter, train_mean_max_iter, color='blue', label='Training ROC_AUC')
plt.plot(param_range_max_iter, test_mean_max_iter, color='green', label='Validation ROC_AUC')
plt.title('Validation Curve for SGD Classifier (Max Iterations)')
plt.xlabel('Max Iterations')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.show()

# %%
# Random Forest Classifier with RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import time

# Define a smaller parameter grid
param_grid_rf = {
    'n_estimators': [100],
    'max_depth': [None, 5],
    'min_samples_split': [2],
    'min_samples_leaf': [1]
}

# Instantiate the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)

# Perform Randomized Search Cross Validation
start_time = time.time()
random_search_rf = RandomizedSearchCV(estimator=rf_model, param_distributions=param_grid_rf, n_iter=2, scoring='roc_auc', cv=2, verbose=2, n_jobs=-1)

# Fit the model
random_search_rf.fit(X_train_smote, y_train_smote)
end_time = time.time()
print("Training Time:", round(end_time - start_time, 2), "seconds")

# Get the best parameters
best_params_rf = random_search_rf.best_params_

# Instantiate the model with best parameters
best_rf_model = RandomForestClassifier(**best_params_rf, random_state=42)

# Fit the model on the training data
best_rf_model.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred_rf = best_rf_model.predict(X_train_smote)

# Confusion matrix
confusion_rf_train = metrics.confusion_matrix(y_train_smote, y_train_pred_rf)
print("Confusion Matrix (Train Set):\n", confusion_rf_train)

# Accuracy
accuracy_rf_train = metrics.accuracy_score(y_train_smote, y_train_pred_rf)
print("Accuracy (Train Set):", accuracy_rf_train)

# Sensitivity
sensitivity_rf_train = confusion_rf_train[1, 1] / float(confusion_rf_train[1, 1] + confusion_rf_train[1, 0])
print("Sensitivity (Train Set):", sensitivity_rf_train)

# Specificity
specificity_rf_train = confusion_rf_train[0, 0] / float(confusion_rf_train[0, 0] + confusion_rf_train[0, 1])
print("Specificity (Train Set):", specificity_rf_train)

# Classification report
print("Classification Report (Train Set):\n", classification_report(y_train_smote, y_train_pred_rf))

# Predicted probability
y_train_pred_proba_rf = best_rf_model.predict_proba(X_train_smote)[:, 1]

# ROC curve
draw_roc(y_train_smote, y_train_pred_proba_rf)

# Predictions on the test set
y_test_pred_rf = best_rf_model.predict(X_test)

# Confusion matrix
confusion_rf_test = metrics.confusion_matrix(y_test, y_test_pred_rf)
print("Confusion Matrix (Test Set):\n", confusion_rf_test)

# Accuracy
accuracy_rf_test = metrics.accuracy_score(y_test, y_test_pred_rf)
print("Accuracy (Test Set):", accuracy_rf_test)

# Sensitivity
sensitivity_rf_test = confusion_rf_test[1, 1] / float(confusion_rf_test[1, 1] + confusion_rf_test[1, 0])
print("Sensitivity (Test Set):", sensitivity_rf_test)

# Specificity
specificity_rf_test = confusion_rf_test[0, 0] / float(confusion_rf_test[0, 0] + confusion_rf_test[0, 1])
print("Specificity (Test Set):", specificity_rf_test)

# Classification report
print("Classification Report (Test Set):\n", classification_report(y_test, y_test_pred_rf))

# Predicted probability
y_test_pred_proba_rf = best_rf_model.predict_proba(X_test)[:, 1]

# ROC curve
draw_roc(y_test, y_test_pred_proba_rf)
#ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# Training Time: 780.94 seconds
# Confusion Matrix (Train Set):
#  [[227449      0]
#  [     0 227449]]
# Accuracy (Train Set): 1.0
# Sensitivity (Train Set): 1.0
# Specificity (Train Set): 1.0
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898
# Confusion Matrix (Test Set):
#  [[56820    46]
#  [   19    77]]
# Accuracy (Test Set): 0.9988588883817282
# Sensitivity (Test Set): 0.8020833333333334
# Specificity (Test Set): 0.9991910807864102
# Classification Report (Test Set):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
# ...

# %%
# Define range of hyperparameters
param_range_max_depth = [None, 5]

# Calculate validation curve for max_depth
train_scores_max_depth, test_scores_max_depth = validation_curve(
    RandomForestClassifier(random_state=42, n_estimators=100),
    X_train_smote,
    y_train_smote,
    param_name="max_depth",
    param_range=param_range_max_depth,
    cv=3,  # Assuming 3-fold cross-validation for faster computation
    scoring="roc_auc",
    n_jobs=-1  # Parallelize computation
)

# Calculate mean and standard deviation for train and test scores
train_mean_max_depth = np.mean(train_scores_max_depth, axis=1)
train_std_max_depth = np.std(train_scores_max_depth, axis=1)
test_mean_max_depth = np.mean(test_scores_max_depth, axis=1)
test_std_max_depth = np.std(test_scores_max_depth, axis=1)

# Plot validation curve for max_depth
plt.figure(figsize=(10, 6))
plt.plot(param_range_max_depth, train_mean_max_depth, color='blue', label='Training AUC')
plt.plot(param_range_max_depth, test_mean_max_depth, color='green', label='Validation AUC')
plt.title('Validation Curve for Random Forest Classifier (Max Depth)')
plt.xlabel('Max Depth')
plt.ylabel('AUC')
plt.legend(loc='lower right')
plt.show()
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

def draw_roc(y_true, y_pred_proba):
    roc_auc = roc_auc_score(y_true, y_pred_proba)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.plot(y_pred_proba, y_true, marker='.', color='red')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

# %%
# Define range of hyperparameters for Random Forest
param_range_n_estimators_rf = [50, 100, 150]
param_range_max_depth_rf = [5, 10, 15]

# Calculate validation curve for n_estimators
train_scores_rf_n_estimators, test_scores_rf_n_estimators = validation_curve(RandomForestClassifier(), X_train_smote, y_train_smote, param_name="n_estimators", param_range=param_range_n_estimators_rf, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores for n_estimators
train_mean_rf_n_estimators = np.mean(train_scores_rf_n_estimators, axis=1)
train_std_rf_n_estimators = np.std(train_scores_rf_n_estimators, axis=1)
test_mean_rf_n_estimators = np.mean(test_scores_rf_n_estimators, axis=1)
test_std_rf_n_estimators = np.std(test_scores_rf_n_estimators, axis=1)

# Plot validation curve for n_estimators
plt.figure(figsize=(10, 6))
plt.plot(param_range_n_estimators_rf, train_mean_rf_n_estimators, color='blue', marker='o', markersize=5, label='Training ROC_AUC')
plt.plot(param_range_n_estimators_rf, test_mean_rf_n_estimators, color='green', linestyle='--', marker='s', markersize=5, label='Validation ROC_AUC')
plt.title('Validation Curve for Random Forest (n_estimators)')
plt.xlabel('Number of Estimators')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.show()

# Calculate validation curve for max_depth
train_scores_rf_max_depth, test_scores_rf_max_depth = validation_curve(RandomForestClassifier(), X_train_smote, y_train_smote, param_name="max_depth", param_range=param_range_max_depth_rf, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores for max_depth
train_mean_rf_max_depth = np.mean(train_scores_rf_max_depth, axis=1)
train_std_rf_max_depth = np.std(train_scores_rf_max_depth, axis=1)
test_mean_rf_max_depth = np.mean(test_scores_rf_max_depth, axis=1)
test_std_rf_max_depth = np.std(test_scores_rf_max_depth, axis=1)

# Plot validation curve for max_depth
plt.figure(figsize=(10, 6))
plt.plot(param_range_max_depth_rf, train_mean_rf_max_depth, color='blue', marker='o', markersize=5, label='Training ROC_AUC')
plt.plot(param_range_max_depth_rf, test_mean_rf_max_depth, color='green', linestyle='--', marker='s', markersize=5, label='Validation ROC_AUC')
plt.title('Validation Curve for Random Forest (max_depth)')
plt.xlabel('Maximum Depth')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import validation_curve
from sklearn.naive_bayes import GaussianNB

# Define range of hyperparameters
param_range_alpha = [0.0001, 0.001, 0.01, 0.1, 1]

# Calculate validation curve for alpha
train_scores_alpha, test_scores_alpha = validation_curve(GaussianNB(), X_train_smote, y_train_smote, param_name="var_smoothing", param_range=param_range_alpha, cv=folds, scoring="roc_auc")

# Calculate mean and standard deviation for train and test scores
train_mean_alpha = np.mean(train_scores_alpha, axis=1)
train_std_alpha = np.std(train_scores_alpha, axis=1)
test_mean_alpha = np.mean(test_scores_alpha, axis=1)
test_std_alpha = np.std(test_scores_alpha, axis=1)

# Plot validation curve for alpha
plt.figure(figsize=(10, 6))
plt.plot(param_range_alpha, train_mean_alpha, color='blue', marker='o', markersize=5, label='Training ROC_AUC')
plt.plot(param_range_alpha, test_mean_alpha, color='green', linestyle='--', marker='s', markersize=5, label='Validation ROC_AUC')
plt.title('Validation Curve for Gaussian Naive Bayes (Alpha)')
plt.xlabel('Alpha (var_smoothing)')
plt.ylabel('ROC_AUC')
plt.legend(loc='lower right')
plt.xscale('log')
plt.show()

# %%
from sklearn.ensemble import VotingClassifier

# Instantiate the best Random Forest model
best_rf_model = RandomForestClassifier(**best_params_rf, random_state=42)

# Instantiate the best XGBoost model
best_xgb_model = XGBClassifier(params=params)

# Create a list of tuples containing the models
estimators = [('Random Forest', best_rf_model), ('XGBoost', best_xgb_model)]

# Instantiate the Voting Classifier with soft voting
fusion_model = VotingClassifier(estimators, voting='soft')

# Fit the fusion model on the training data
fusion_model.fit(X_train_smote, y_train_smote)

# Predictions on the train set
y_train_pred_fusion = fusion_model.predict(X_train_smote)

# Confusion matrix
confusion_fusion_train = confusion_matrix(y_train_smote, y_train_pred_fusion)
print("Confusion Matrix (Train Set):\n", confusion_fusion_train)

# Accuracy
accuracy_fusion_train = metrics.accuracy_score(y_train_smote, y_train_pred_fusion)
print("Accuracy (Train Set):", accuracy_fusion_train)

# Sensitivity
sensitivity_fusion_train = confusion_fusion_train[1, 1] / float(confusion_fusion_train[1, 1] + confusion_fusion_train[1, 0])
print("Sensitivity (Train Set):", sensitivity_fusion_train)

# Specificity
specificity_fusion_train = confusion_fusion_train[0, 0] / float(confusion_fusion_train[0, 0] + confusion_fusion_train[0, 1])
print("Specificity (Train Set):", specificity_fusion_train)

# Classification report
print("Classification Report (Train Set):\n", classification_report(y_train_smote, y_train_pred_fusion))

# Predicted probability
y_train_pred_proba_fusion = fusion_model.predict_proba(X_train_smote)[:, 1]

# ROC curve
draw_roc(y_train_smote, y_train_pred_proba_fusion)

# Predictions on the test set
y_test_pred_fusion = fusion_model.predict(X_test)

# Confusion matrix
confusion_fusion_test = confusion_matrix(y_test, y_test_pred_fusion)
print("Confusion Matrix (Test Set):\n", confusion_fusion_test)

# Accuracy
accuracy_fusion_test = metrics.accuracy_score(y_test, y_test_pred_fusion)
print("Accuracy (Test Set):", accuracy_fusion_test)

# Sensitivity
sensitivity_fusion_test = confusion_fusion_test[1, 1] / float(confusion_fusion_test[1, 1] + confusion_fusion_test[1, 0])
print("Sensitivity (Test Set):", sensitivity_fusion_test)

# Specificity
specificity_fusion_test = confusion_fusion_test[0, 0] / float(confusion_fusion_test[0, 0] + confusion_fusion_test[0, 1])
print("Specificity (Test Set):", specificity_fusion_test)

# Classification report
print("Classification Report (Test Set):\n", classification_report(y_test, y_test_pred_fusion))

# Predicted probability
y_test_pred_proba_fusion = fusion_model.predict_proba(X_test)[:, 1]

# ROC curve
draw_roc(y_test, y_test_pred_proba_fusion)
# Out:
# [22:31:20] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "params" } are not used.
#
# Confusion Matrix (Train Set):
#  [[227446      3]
#  [     0 227449]]
# Accuracy (Train Set): 0.9999934051149928
# Sensitivity (Train Set): 1.0
# Specificity (Train Set): 0.9999868102299856
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898
# Confusion Matrix (Test Set):
#  [[56821    45]
#  [   20    76]]
# Accuracy (Test Set): 0.9988588883817282
# Sensitivity (Test Set): 0.7916666666666666
# Specificity (Test Set): 0.9992086659867055
# Classification Report (Test Set):
# ...

# %%
pip install streamlit -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile app.py
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import streamlit as st
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# Load data
data = pd.read_csv('creditcard.csv')

# Separate legitimate and fraudulent transactions
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# Undersample legitimate transactions to balance the classes
legit_sample = legit.sample(n=len(fraud), random_state=2)
data = pd.concat([legit_sample, fraud], axis=0)

# Split data into features and target
X = data.drop(columns="Class", axis=1)
y = data["Class"]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)

# Preprocessing
scaler = StandardScaler()
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])
X_test['Amount'] = scaler.transform(X_test[['Amount']])

imputer = SimpleImputer(strategy="mean")
X_train = imputer.fit_transform(X_train)

sm = SMOTE(random_state=27)
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# Instantiate the best Random Forest model
best_rf_model = RandomForestClassifier(**best_params_rf, random_state=42)

# Instantiate the best XGBoost model
best_xgb_model = XGBClassifier(params=params)

# Create a list of tuples containing the models
estimators = [('Random Forest', best_rf_model), ('XGBoost', best_xgb_model)]

# Instantiate the Voting Classifier with soft voting
fusion_model = VotingClassifier(estimators, voting='soft')

# Fit the fusion model on the training data
fusion_model.fit(X_train_smote, y_train_smote)

# Evaluate model performance
train_acc = accuracy_score(fusion_model.predict(X_train_smote), y_train_smote)
test_acc = accuracy_score(fusion_model.predict(X_test), y_test)

# Create Streamlit app
st.title("Credit Card Fraud Detection Model")
st.write("Enter the following features to check if the transaction is legitimate or fraudulent:")

# Create input fields for user to enter feature values
input_df = st.text_input('Input All features')
input_df_lst = input_df.split(',')

# Create a button to submit input and get prediction
submit = st.button("Submit")

# %%
# !wget -q -O - ipv4.icanhazip.com

# %%
# !streamlit run app.py & npx localtunnel --port 8501
